# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt
from ipywidgets import interact
from packages.utils.videos import VideoSource

# %%
x = np.arange(0, 2*np.pi)
vs = VideoSource('./videos/example_01.mp4')

# %%
fig1, axes1 = plt.subplots(figsize=(8,6))

def update_plot(T=0.1):
    axes1.cla()
    axes1.plot(x, np.sin(x*T))
interact(update_plot, T=(0, 1, 0.1))
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(FloatSlider(value=0.1, description='T', max=1.0), Output()), _dom_classes=('widget-inter…
# <function __main__.update_plot(T=0.1)>

# %%
fig2, axes2 = plt.subplots()

def update_plot(T=0.1):
    axes2.cla()
    axes2.plot(x, np.sin(2*x*T))
interact(update_plot, T=(2.0, 4.0, 0.1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=2.0, description='T', max=4.0, min=2.0), Output()), _dom_classes=('wid…
# <function __main__.update_plot(T=0.1)>

# %%
fig3, axes3 = plt.subplots()

def update_image(f=0):
    axes3.cla()
    axes3.imshow(vs.get_frame(f))


interact(update_image, f=(0, vs.get_total_frames() - 1, 1))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='f', max=1282), Output()), _dom_classes=('widget-interact…
# <function __main__.update_image(f=0)>
